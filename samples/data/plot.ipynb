# %%
import matplotlib
import matplotlib.pyplot as plt


import numpy as np

# %% [markdown]
# ## Single link performance

# %%
# Load data
x = [i+1 for i in range(1000)]
y1 = np.loadtxt('data_normal.txt')
y2 = np.loadtxt('data_random.txt')
y3 = np.loadtxt('data_fix_epi.txt')
y4 = np.loadtxt('data_bandits.txt')

# %%
# Print performance ratio
print('1-A2C/Random Strategy (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y2[len(y2)-1]))
print('1-A2C/Fixed-within-each-episode (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y3[len(y3)-1]))
print('1-A2C/Multi-armed bandits (episode 1000) = {:.2%}'.format(1-y1[len(y1)-1]/y4[len(y4)-1]))
print('1-A2C/Multi-armed bandits (episode 200) = {:.2%}'.format(1-y1[200-1]/y4[200-1]))
print('1-A2C/Multi-armed bandits (episode 100) = {:.2%}'.format(1-y1[100-1]/y4[100-1]))
# Out:
# 1-A2C/Random Strategy (episode 1000)= 23.60%
# 1-A2C/Fixed-within-each-episode (episode 1000)= 28.59%
# 1-A2C/Multi-armed bandits (episode 1000) = 0.85%
# 1-A2C/Multi-armed bandits (episode 200) = 6.42%
# 1-A2C/Multi-armed bandits (episode 100) = 8.79%

# %%
# Plot
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.xlabel('Episode')
plt.ylabel('Cumulative Flow Completion Time')
plt.title('Cumulative Flow Completion Time Comparison')
plt.legend(['A2C', 'Random strategy', 'Fixed-within-each-episode','Multi-armed bandits'])
plt.savefig('flow_time_4lines.eps', format='eps', bbox_inches = "tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Six-node diamond network performance

# %%
# Load data
x = [i+1 for i in range(1000)]
y1 = np.loadtxt('data_mp_normal_1.txt')
y2 = np.loadtxt('data_mp_normal_no_training.txt')
y3 = np.loadtxt('data_mp_random.txt')
y4 = np.loadtxt('data_mp_fix_epi.txt')
y5 = np.loadtxt('data_mp_bandits_2.txt')
print(np.size(y1))
# Out:
# 1000

# %%
# Print performance ratio
print('1-A2C/Random Strategy (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y2[len(y2)-1]))
print('1-A2C/Random Strategy (episode 100)= {:.2%}'.format(1-y1[100-1]/y2[100-1]))
print('1-A2C/Fixed-within-each-episode (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y3[len(y3)-1]))
print('1-A2C/Fixed-within-each-episode (episode 100)= {:.2%}'.format(1-y1[100-1]/y3[100-1]))
print('1-A2C/Multi-armed bandits (episode 1000) = {:.2%}'.format(1-y1[len(y1)-1]/y4[len(y4)-1]))
print('1-A2C/Multi-armed bandits (episode 100) = {:.2%}'.format(1-y1[200-1]/y4[200-1]))
print('1-A2C/Multi-armed bandits (episode 200) = {:.2%}'.format(1-y1[100-1]/y4[100-1]))
# Out:
# 1-A2C/Random Strategy (episode 1000)= -147.06%
# 1-A2C/Random Strategy (episode 100)= -144.70%
# 1-A2C/Fixed-within-each-episode (episode 1000)= -77.09%
# 1-A2C/Fixed-within-each-episode (episode 100)= -78.44%
# 1-A2C/Multi-armed bandits (episode 1000) = -44.78%
# 1-A2C/Multi-armed bandits (episode 100) = -43.00%
# 1-A2C/Multi-armed bandits (episode 200) = -48.22%

# %%
# Plot
plt.plot(x, y1, x, y2, x, y3, x, y4, x, y5)
plt.xlabel('Episode')
plt.ylabel('Cumulative Flow Completion Time')
plt.title('Cumulative Flow Completion Time Comparison')
plt.legend(['A2C + offline training', 'A2C-without-training','Random strategy', 'Fixed-within-each-episode', 'Multi-armed bandits'])
plt.savefig('flow_time_mp.eps', format='eps', bbox_inches = "tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Data-driven six-node diamond network performance

# %%
# Load data
x = [i+1 for i in range(1000)]
y1 = np.loadtxt('data_testbed_a2c.txt')
y2 = np.loadtxt('data_testbed_random.txt')
y3 = np.loadtxt('data_testbed_fix_epi.txt')
y4 = np.loadtxt('data_testbed_bandits.txt')
print(np.size(y1))
# Out:
# 1000

# %%
# Print performance ratio
print('1-A2C/Random Strategy (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y2[len(y2)-1]))
print('1-A2C/Random Strategy (episode 100)= {:.2%}'.format(1-y1[100-1]/y2[100-1]))
print('1-A2C/Fixed-within-each-episode (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y3[len(y3)-1]))
print('1-A2C/Fixed-within-each-episode (episode 100)= {:.2%}'.format(1-y1[100-1]/y3[100-1]))
print('1-A2C/Multi-armed bandits (episode 1000) = {:.2%}'.format(1-y1[len(y1)-1]/y4[len(y4)-1]))
print('1-A2C/Multi-armed bandits (episode 100) = {:.2%}'.format(1-y1[200-1]/y4[200-1]))
print('1-A2C/Multi-armed bandits (episode 200) = {:.2%}'.format(1-y1[100-1]/y4[100-1]))
# Out:
# 1-A2C/Random Strategy (episode 1000)= 68.60%
# 1-A2C/Random Strategy (episode 100)= 68.91%
# 1-A2C/Fixed-within-each-episode (episode 1000)= 96.70%
# 1-A2C/Fixed-within-each-episode (episode 100)= 96.63%
# 1-A2C/Multi-armed bandits (episode 1000) = 31.46%
# 1-A2C/Multi-armed bandits (episode 100) = 47.38%
# 1-A2C/Multi-armed bandits (episode 200) = 53.51%

# %%
# Plot
plt.plot(x, y1, x, y2, x, y3, x, y4)
plt.xlabel('Episode')
plt.ylabel('Cumulative Flow Completion Time')
plt.title('Cumulative Flow Completion Time Comparison')
plt.legend(['A2C', 'Random strategy', 'Fixed-within-each-episode', 'Multi-armed bandits'])
plt.savefig('flowtime_mp_data.eps', format='eps', bbox_inches = "tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Sending rate control using bandwidth capacity data

# %%
# Load data
x = [i+1 for i in range(1000)]
y1 = np.loadtxt('data_sd_rate_normal.txt')
y2 = np.loadtxt('data_sd_rate_random.txt')
# y3 = np.loadtxt('data_testbed_fix_epi.txt')
# y4 = np.loadtxt('data_testbed_bandits.txt')
print(np.size(y1))
# Out:
# 1000

# %%
# Print performance ratio
print('1-A2C/Random Strategy (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y2[len(y2)-1]))
# print('1-A2C/Random Strategy (episode 100)= {:.2%}'.format(1-y1[100-1]/y2[100-1]))
# print('1-A2C/Fixed-within-each-episode (episode 1000)= {:.2%}'.format(1-y1[len(y1)-1]/y3[len(y3)-1]))
# print('1-A2C/Fixed-within-each-episode (episode 100)= {:.2%}'.format(1-y1[100-1]/y3[100-1]))
# print('1-A2C/Multi-armed bandits (episode 1000) = {:.2%}'.format(1-y1[len(y1)-1]/y4[len(y4)-1]))
# print('1-A2C/Multi-armed bandits (episode 100) = {:.2%}'.format(1-y1[200-1]/y4[200-1]))
# print('1-A2C/Multi-armed bandits (episode 200) = {:.2%}'.format(1-y1[100-1]/y4[100-1]))
# Out:
# 1-A2C/Random Strategy (episode 1000)= -1.66%
